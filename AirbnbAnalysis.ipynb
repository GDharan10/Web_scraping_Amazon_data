# %% [markdown]
# <a href="https://colab.research.google.com/github/GDharan10/Web_scraping_Amazon_data/blob/main/AirbnbAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.9/676.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 10.3 MB/s eta 0:00:00
# ...

# %%
#Connections
import pymongo

import pandas as pd

# %%
#MongoDB
client = pymongo.MongoClient("mongodb+srv://giri:giri1005@cluster0.oufax3z.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client["sample_airbnb"]
collection = db["listingsAndReviews"]

# %%
#Fledgling data from MongoDB
data_list = []
for data in collection.find({},{"_id": 0}):
  data_list.append(data)

df = pd.DataFrame(data_list)

# %%
pd.set_option("display.max_column", None)

# %%
df
# Out:
#                                 listing_url  \
# 0     https://www.airbnb.com/rooms/10059872
# 1     https://www.airbnb.com/rooms/10066928
# 2     https://www.airbnb.com/rooms/10059244
# 3     https://www.airbnb.com/rooms/10009999
# 4     https://www.airbnb.com/rooms/10030955
# ...                                     ...
# 5550   https://www.airbnb.com/rooms/9834391
# 5551   https://www.airbnb.com/rooms/9848837
# 5552   https://www.airbnb.com/rooms/9985696
# 5553   https://www.airbnb.com/rooms/9937100
# 5554   https://www.airbnb.com/rooms/9951865
#
#                                                   name  \
# 0                   Soho Cozy, Spacious and Convenient
# 1                       3 chambres au coeur du Plateau
# 2     Ligne verte - à 15 min de métro du centre ville.
# 3                         Horto flat with small garden
# 4                          Apt Linda Vista Lagoa - Rio
# ...                                                ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   listing_url            5555 non-null   object
#  1   name                   5555 non-null   object
#  2   summary                5555 non-null   object
#  3   space                  5555 non-null   object
#  4   description            5555 non-null   object
#  5   neighborhood_overview  5555 non-null   object
#  6   notes                  5555 non-null   object
#  7   transit                5555 non-null   object
#  8   access                 5555 non-null   object
#  9   interaction            5555 non-null   object
#  10  house_rules            5555 non-null   object
#  11  property_type          5555 non-null   object
#  12  room_type              5555 non-null   object
#  13  bed_type               5555 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# first_review             1388
# last_review              1388
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# weekly_price             4841
# extra_people                0
# guests_included             0
# ...

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6e764a0154be> in <cell line: 1>()
# ----> 1 df.duplicated().sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6660         else:
#    6661             vals = (col.values for name, col in self.items() if name in subset)
# -> 6662             labels, shape = map(list, zip(*map(f, vals)))
#    6663
#    6664             ids = get_group_index(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in f(vals)
#    6628
#    6629         def f(vals) -> tuple[np.ndarray, int]:
# -> 6630             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631             return labels.astype("i8", copy=False), len(shape)
#    6632
#
# ...
